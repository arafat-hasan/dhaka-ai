# %% [markdown]
# <a href="https://colab.research.google.com/github/arafat-hasan/dhaka-ai/blob/master/YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !git clone https://github.com/arafat-hasan/yolov5.git

# %%
# %cd /content/yolov5
# !pwd

# %%
# !pip3 install wandb -qr requirements.txt # install requirements.txt

# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))

# %%
# !rm -rf runs
# !ln -s "/gdrive/My Drive/kaggle/dhaka-ai/yolov5/runs" runs

# %%
# !rm -rf wandb
# !ln -s "/gdrive/My Drive/kaggle/dhaka-ai/yolov5/wandb" wandb

# %%
# %cd /content

# %%
# !git clone https://github.com/arafat-hasan/dhaka-ai.git

# %%
# %cd /content/dhaka-ai
# %ls

# %%
# !./generate-yolo-dataset.sh "/gdrive/My Drive/kaggle/dhaka-ai-dataset/train/Final Train Dataset"

# %%
# %cd /content/yolov5
# !pwd

# %%
# Start tensorboard (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python train.py --img 1024 --batch 4 --epochs 5 --data /content/dhaka-ai/dhaka_ai.yaml --weights yolov5s.pt --cache

# %%
# !ls

# %%
# !rm -rf inference
# !ln -s "/gdrive/My Drive/kaggle/dhaka-ai/yolov5/inference" inference

# %%
# !python detect.py --weights '/gdrive/My Drive/kaggle/dhaka-ai/yolov5/runs/exp1/weights/best.pt' --img 1024 --conf 0.25 --source '/gdrive/My Drive/kaggle/dhaka-ai-dataset/sample'

# %%
# !ls inference/output -la

# %%
Image(filename='inference/output/Asraf_50_jpg.rf.7026694f0b9f37a6790982295c7e8663.jpg', width=1024)
